# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import joblib
import os

# %%
# --- Config ---
DATASET_PATH = "Dataset.csv"  # dataset file
ALL_FEATURES = [
    'cnn_pca1', 'AVR', 'vessel_redness', 'sclera_mean_hue',
    'AV_sat_diff', 'tortuosity', 'sclera_redness', 'vessel_density',
    'perivascular_contrast', 'pulse_std'
]
TARGET_COL = 'blood_group'

# %%
# --- Step 1: Load Dataset ---
try:
    df = pd.read_csv(DATASET_PATH)
except FileNotFoundError:
    print(f"Error: '{DATASET_PATH}' not found.")
    exit()

# %%
# --- Step 2: Clean Data ---
df_clean = df.dropna(subset=ALL_FEATURES + [TARGET_COL])

# --- Step 3: Separate features and target ---
X = df_clean[ALL_FEATURES]
y = df_clean[TARGET_COL]

# --- Step 4: Encode target labels ---
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# %%
# --- Step 5: Scale features ---
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# --- Step 6: Train-Test Split ---
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42, stratify=y_encoded
)
y_test_labels = np.argmax(y_test, axis=1)

# %%
# --- Step 7: Build Model ---
model = Sequential([
    Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(y_categorical.shape[1], activation='softmax')
])

# %%
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# --- Step 8: Train Model ---
early_stopping = EarlyStopping(monitor='val_accuracy', patience=20, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 1s 7ms/step - loss: 2.0669 - accuracy: 0.1555 - val_loss: 2.0368 - val_accuracy: 0.2031
# Epoch 2/200
# 40/40 [==============================] - 0s 4ms/step - loss: 2.0164 - accuracy: 0.2164 - val_loss: 1.9741 - val_accuracy: 0.2594
# Epoch 3/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.9365 - accuracy: 0.2523 - val_loss: 1.8860 - val_accuracy: 0.2781
# Epoch 4/200
# 40/40 [==============================] - 0s 3ms/step - loss: 1.8230 - accuracy: 0.3203 - val_loss: 1.7699 - val_accuracy: 0.2812
# Epoch 5/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.6955 - accuracy: 0.3359 - val_loss: 1.6410 - val_accuracy: 0.3000
# Epoch 6/200
# 40/40 [==============================] - 0s 3ms/step - loss: 1.5801 - accuracy: 0.3641 - val_loss: 1.5109 - val_accuracy: 0.3531
# Epoch 7/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.4631 - accuracy: 0.4219 - val_loss: 1.3834 - val_accuracy: 0.4187
# Epoch 8/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.3697 - accuracy: 0.4484 - val_loss: 1.2763 - val_accuracy: 0.4563
# Epoch 9/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.3072 - accuracy: 0.4586 - val_loss: 1.1895 - val_accuracy: 0.5063
# Epoch 10/200
# 40/40 [==============================] - 0s 3ms/step - loss: 1.2538 - accuracy: 0.4898 - val_loss: 1.1135 - val_accuracy: 0.5406
# Epoch 11/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.1968 - accuracy: 0.5039 - val_loss: 1.0510 - val_accuracy: 0.5562
# Epoch 12/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.1539 - accuracy: 0.5234 - val_loss: 1.0012 - val_accuracy: 0.5781
# Epoch 13/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.1182 - accuracy: 0.5289 - val_loss: 0.9447 - val_accuracy: 0.6313
# Epoch 14/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0796 - accuracy: 0.5531 - val_loss: 0.9088 - val_accuracy: 0.6469
# Epoch 15/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0707 - accuracy: 0.5508 - val_loss: 0.8636 - val_accuracy: 0.6781
# Epoch 16/200
# 40/40 [==============================] - 0s 4ms/step - loss: 1.0093 - accuracy: 0.5758 - val_loss: 0.8298 - val_accuracy: 0.6812
# Epoch 17/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.9824 - accuracy: 0.5781 - val_loss: 0.8083 - val_accuracy: 0.6687
# Epoch 18/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.9525 - accuracy: 0.6211 - val_loss: 0.7988 - val_accuracy: 0.6656
# Epoch 19/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.9104 - accuracy: 0.6195 - val_loss: 0.7343 - val_accuracy: 0.7281
# Epoch 20/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.9091 - accuracy: 0.6164 - val_loss: 0.7207 - val_accuracy: 0.7281
# Epoch 21/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.8849 - accuracy: 0.6375 - val_loss: 0.6961 - val_accuracy: 0.7312
# Epoch 22/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.8487 - accuracy: 0.6422 - val_loss: 0.6703 - val_accuracy: 0.7437
# Epoch 23/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.8506 - accuracy: 0.6430 - val_loss: 0.6533 - val_accuracy: 0.7594
# Epoch 24/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.8254 - accuracy: 0.6703 - val_loss: 0.6295 - val_accuracy: 0.7656
# Epoch 25/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.8182 - accuracy: 0.6500 - val_loss: 0.5981 - val_accuracy: 0.7781
# Epoch 26/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7638 - accuracy: 0.6891 - val_loss: 0.5890 - val_accuracy: 0.7750
# Epoch 27/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7620 - accuracy: 0.6984 - val_loss: 0.5676 - val_accuracy: 0.7906
# Epoch 28/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7538 - accuracy: 0.6766 - val_loss: 0.5543 - val_accuracy: 0.7937
# Epoch 29/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7454 - accuracy: 0.6750 - val_loss: 0.5284 - val_accuracy: 0.8125
# Epoch 30/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7673 - accuracy: 0.6648 - val_loss: 0.5202 - val_accuracy: 0.8219
# Epoch 31/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7142 - accuracy: 0.7047 - val_loss: 0.5036 - val_accuracy: 0.8156
# Epoch 32/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6906 - accuracy: 0.7195 - val_loss: 0.4818 - val_accuracy: 0.8625
# Epoch 33/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6391 - accuracy: 0.7461 - val_loss: 0.4789 - val_accuracy: 0.8188
# Epoch 34/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6599 - accuracy: 0.7336 - val_loss: 0.4482 - val_accuracy: 0.8625
# Epoch 35/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6549 - accuracy: 0.7227 - val_loss: 0.4428 - val_accuracy: 0.8687
# Epoch 36/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6313 - accuracy: 0.7312 - val_loss: 0.4345 - val_accuracy: 0.8531
# Epoch 37/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6561 - accuracy: 0.7336 - val_loss: 0.4249 - val_accuracy: 0.8625
# Epoch 38/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5938 - accuracy: 0.7555 - val_loss: 0.4095 - val_accuracy: 0.8625
# Epoch 39/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5994 - accuracy: 0.7547 - val_loss: 0.3930 - val_accuracy: 0.8687
# Epoch 40/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5737 - accuracy: 0.7805 - val_loss: 0.4053 - val_accuracy: 0.8625
# Epoch 41/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5998 - accuracy: 0.7719 - val_loss: 0.3810 - val_accuracy: 0.8656
# Epoch 42/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5568 - accuracy: 0.7781 - val_loss: 0.3675 - val_accuracy: 0.8781
# Epoch 43/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5425 - accuracy: 0.7758 - val_loss: 0.3501 - val_accuracy: 0.9031
# Epoch 44/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5568 - accuracy: 0.7820 - val_loss: 0.3475 - val_accuracy: 0.8938
# Epoch 45/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5331 - accuracy: 0.7852 - val_loss: 0.3365 - val_accuracy: 0.9062
# Epoch 46/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5103 - accuracy: 0.7836 - val_loss: 0.3347 - val_accuracy: 0.9031
# Epoch 47/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5105 - accuracy: 0.7836 - val_loss: 0.3300 - val_accuracy: 0.8969
# Epoch 48/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5167 - accuracy: 0.7789 - val_loss: 0.3293 - val_accuracy: 0.8875
# Epoch 49/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5166 - accuracy: 0.7977 - val_loss: 0.2968 - val_accuracy: 0.9250
# Epoch 50/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4931 - accuracy: 0.7992 - val_loss: 0.3023 - val_accuracy: 0.9062
# Epoch 51/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4815 - accuracy: 0.8109 - val_loss: 0.2876 - val_accuracy: 0.9156
# Epoch 52/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.4731 - accuracy: 0.8031 - val_loss: 0.2746 - val_accuracy: 0.9344
# Epoch 53/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4588 - accuracy: 0.8258 - val_loss: 0.2653 - val_accuracy: 0.9344
# Epoch 54/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4742 - accuracy: 0.8086 - val_loss: 0.2607 - val_accuracy: 0.9344
# Epoch 55/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4335 - accuracy: 0.8305 - val_loss: 0.2632 - val_accuracy: 0.9375
# Epoch 56/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4358 - accuracy: 0.8367 - val_loss: 0.2647 - val_accuracy: 0.9312
# Epoch 57/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4219 - accuracy: 0.8406 - val_loss: 0.2463 - val_accuracy: 0.9375
# Epoch 58/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4112 - accuracy: 0.8430 - val_loss: 0.2163 - val_accuracy: 0.9531
# Epoch 59/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4128 - accuracy: 0.8328 - val_loss: 0.2582 - val_accuracy: 0.9156
# Epoch 60/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4169 - accuracy: 0.8328 - val_loss: 0.2556 - val_accuracy: 0.9375
# Epoch 61/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4121 - accuracy: 0.8406 - val_loss: 0.2491 - val_accuracy: 0.9344
# Epoch 62/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3868 - accuracy: 0.8430 - val_loss: 0.2054 - val_accuracy: 0.9531
# Epoch 63/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3990 - accuracy: 0.8445 - val_loss: 0.2076 - val_accuracy: 0.9500
# Epoch 64/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3901 - accuracy: 0.8531 - val_loss: 0.2000 - val_accuracy: 0.9438
# Epoch 65/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3747 - accuracy: 0.8664 - val_loss: 0.2096 - val_accuracy: 0.9438
# Epoch 66/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3624 - accuracy: 0.8523 - val_loss: 0.2221 - val_accuracy: 0.9406
# Epoch 67/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.8602 - val_loss: 0.1929 - val_accuracy: 0.9406
# Epoch 68/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3475 - accuracy: 0.8641 - val_loss: 0.1792 - val_accuracy: 0.9500
# Epoch 69/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3326 - accuracy: 0.8711 - val_loss: 0.1747 - val_accuracy: 0.9438
# Epoch 70/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3568 - accuracy: 0.8703 - val_loss: 0.1847 - val_accuracy: 0.9406
# Epoch 71/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3657 - accuracy: 0.8641 - val_loss: 0.1743 - val_accuracy: 0.9469
# Epoch 72/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3337 - accuracy: 0.8789 - val_loss: 0.1830 - val_accuracy: 0.9406
# Epoch 73/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3336 - accuracy: 0.8695 - val_loss: 0.1615 - val_accuracy: 0.9531
# Epoch 74/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2976 - accuracy: 0.9008 - val_loss: 0.1674 - val_accuracy: 0.9500
# Epoch 75/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3255 - accuracy: 0.8773 - val_loss: 0.1647 - val_accuracy: 0.9500
# Epoch 76/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3163 - accuracy: 0.8820 - val_loss: 0.1569 - val_accuracy: 0.9469
# Epoch 77/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3065 - accuracy: 0.8883 - val_loss: 0.1539 - val_accuracy: 0.9500
# Epoch 78/200
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3074 - accuracy: 0.8852 - val_loss: 0.1598 - val_accuracy: 0.9500

# %%
# --- Step 9: Evaluate Model ---
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"\n✅ Model Accuracy on Test Data: {accuracy * 100:.2f}%")

# --- Step 10: Save Model, Scaler, Encoder ---
#model.save('trained_model.h5')
#joblib.dump(scaler, 'scaler.pkl')
#joblib.dump(encoder, 'encoder.pkl')
print("\n💾 Saved: trained_model.h5, scaler.pkl, encoder.pkl")
# Out:
# ✅ Model Accuracy on Test Data: 96.25%
#
# 💾 Saved: trained_model.h5, scaler.pkl, encoder.pkl

# %%
# --- Step 11: Accuracy & Loss Graph ---
plt.style.use('seaborn-v0_8-whitegrid')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
ax1.plot(history.history['accuracy'], label='Train Accuracy')
ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(history.history['loss'], label='Train Loss')
ax2.plot(history.history['val_loss'], label='Validation Loss')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

#plt.savefig('accuracy_loss_graphs.png')
#plt.close(fig)

# %%
# --- Step 12: Confusion Matrix ---
y_pred_probs = model.predict(X_test, verbose=0)
y_pred_labels = np.argmax(y_pred_probs, axis=1)
cm = confusion_matrix(y_test_labels, y_pred_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.title('Confusion Matrix')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
#plt.savefig('confusion_matrix.png')
#plt.close()
# Out:
# Text(0.5, 63.583333333333314, 'Predicted Label')

# %%
# --- Step 13: Classification Report ---
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred_labels, target_names=encoder.classes_))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           A+       1.00      0.96      0.98        53
#           A-       0.90      1.00      0.95        52
#          AB+       1.00      0.93      0.96        55
#          AB-       0.98      1.00      0.99        58
#           B+       1.00      0.90      0.95        40
#           B-       0.93      1.00      0.96        52
#           O+       1.00      0.89      0.94        44
#           O-       0.92      1.00      0.96        46
#
#     accuracy                           0.96       400
#    macro avg       0.97      0.96      0.96       400
# weighted avg       0.97      0.96      0.96       400

# %%
# --- Step 14: Feature Pairplot (First 5 Features) ---
sns.pairplot(df_clean, vars=ALL_FEATURES[:5], hue=TARGET_COL, plot_kws={'alpha': 0.6}, diag_kind='hist')
plt.suptitle('Pairplot of First 5 Features by Blood Group', y=1.02)
plt.savefig('feature_pairplot.png')
#plt.close()

print("\n✅ Training complete. All files saved successfully.")
# Out:
# ✅ Training complete. All files saved successfully.
